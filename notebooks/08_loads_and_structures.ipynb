# %% [markdown]
# # 8 — Loads and structures
#
# The final explorer connects aerodynamic limits and gust response to the spanwise loads carried by a wing. Use it after maneuver envelopes, gust loading, limit versus ultimate load, shear, and bending moment have been introduced.
#
# The structural model remains intentionally simple: its job is to show which flight case sizes the structure and which assumptions still need engineering work.

# %%
from flightlab.explorers import loads_explorer

loads_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Change mass and maximum lift coefficient and explain both stall and corner-speed trends.
# 2. Increase gust velocity and identify where the gust boundary becomes governing.
# 3. Change the span-load factor and track root bending moment.
# 4. Copy the **Python** and add material allowables, spar geometry, inertial relief, or stiffness calculations.

# %%
# Extend the governing load case into spar sizing or deflection here.
