# %% [markdown]
# # 5 — Complete-aircraft drag
#
# This explorer combines parasite, induced, viscous lift-dependent, and conceptual wave drag into a complete polar. Use it only after students have met each major contribution separately.
#
# The purpose is to interpret why a polar has its shape and how the balance changes—not merely to read off maximum lift-to-drag ratio.

# %%
from flightlab.explorers import drag_explorer

drag_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Change assumed span efficiency and identify which part of the polar moves.
# 2. Add a cooling allowance and decide whether its importance depends on lift coefficient.
# 3. Compare aircraft at realistic speeds and altitudes; a drag polar is not independent of Reynolds and Mach number.
# 4. Copy the **Python** to make a force-versus-speed or altitude comparison.

# %%
# Extend the selected polar into a force, speed, or altitude analysis.
