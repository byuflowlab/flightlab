# %% [markdown]
# # 4 — Stability and trim
#
# Use this after the ideas of center of gravity, neutral point, tail volume, and pitching-moment balance have been introduced. The interface focuses on the distinction between being able to trim at one condition and retaining an acceptable static margin.
#
# It deliberately exposes tail lift and required incidence so stability does not collapse into a single pass/fail number.

# %%
from flightlab.explorers import stability_explorer

stability_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Move the CG aft and predict the neutral-point and static-margin behavior before running.
# 2. Resize the horizontal tail and watch both stability margin and trim requirements.
# 3. Change flight speed and explain why required lift and tail loading move.
# 4. Use the generated **Python** as the starting point for a CG sweep or a later dynamic-mode analysis.

# %%
# Build a CG-envelope or tail-size comparison here.
