# %% [markdown]
# # 2 — Airfoil analysis
#
# Use this after introducing two-dimensional section coefficients and Reynolds-number effects. The interface generates low-speed section polars while keeping model confidence and transition assumptions visible.
#
# The goal is not to find a universally best airfoil. It is to identify which section behaves well over the lift-coefficient and Reynolds-number range a particular vehicle will actually use.

# %%
from flightlab.explorers import airfoil_explorer

airfoil_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Hold the section fixed and change Reynolds number by an order of magnitude.
# 2. Compare a conventional section with a high-lift, low-Reynolds-number section.
# 3. Force transition forward and watch both the drag polar and confidence display.
# 4. Do not report a maximum lift coefficient unless the swept range contains an interior lift maximum.
# 5. Copy the **Python** tab into the cell below to compare several polars on common axes.

# %%
# Build your multi-section or multi-Reynolds comparison here.
