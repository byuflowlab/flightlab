# %% [markdown]
# # 7 — Aircraft performance
#
# Use this after a complete drag polar is familiar. It turns the polar into drag-required and power-required curves, then identifies stall, best-glide, minimum-power, and minimum-sink conditions.
#
# The interface emphasizes that these characteristic speeds answer different questions and therefore need not coincide.

# %%
from flightlab.explorers import performance_explorer

performance_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Change mass and compare the characteristic speeds with the best L/D itself.
# 2. Change altitude and distinguish true-airspeed changes from coefficient changes.
# 3. Explain why minimum-power speed is below best-glide speed.
# 4. Copy the **Python**, then add a thrust- or power-available model to analyze climb and ceiling.

# %%
# Add available performance and analyze climb or ceiling here.
