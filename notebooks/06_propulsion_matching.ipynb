# %% [markdown]
# # 6 — Propulsion-system matching
#
# This interface treats battery, controller, motor, and propeller as a coupled system. It is intended for use after voltage sag, motor constants, propeller advance ratio, and component efficiency have been introduced.
#
# Measured-data coverage is displayed alongside the operating point because numerical convergence is not the same as physical credibility.

# %%
from flightlab.explorers import propulsion_explorer

propulsion_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Compare two propeller pitches with the same motor and battery.
# 2. Change battery voltage or motor winding and watch torque balance, current, and speed together.
# 3. Identify where the speed sweep leaves the measured propeller range.
# 4. Copy the **Python** and add explicit current, thrust-margin, and component-mass constraints before selecting a system.

# %%
# Build a constrained component comparison here.
