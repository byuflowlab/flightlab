# %% [markdown]
# # 3 — Wing design
#
# This explorer begins after section aerodynamics and induced drag are familiar. It separates span loading, which controls induced drag, from local section lift coefficient, which helps determine where stall begins.
#
# The controls change span, taper, and washout on an ASW-27-like conceptual planform while holding wing area fixed.

# %%
from flightlab.explorers import wing_design_explorer

wing_design_explorer()

# %% [markdown]
# ## Suggested exploration
#
# 1. Vary taper with zero twist and look for the most nearly elliptical span loading.
# 2. Add washout and distinguish its effect on span efficiency from its effect on outboard local lift.
# 3. Increase span at fixed area and note both the induced-drag benefit and the unmodeled structural consequence.
# 4. Treat the live values as trends; use the higher panel counts in the generated **Python** before reporting numbers.

# %%
# Build a bounded taper–twist or span comparison here.
